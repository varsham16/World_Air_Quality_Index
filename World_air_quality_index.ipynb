# %% [markdown]
# # World Air Quality Index Exercise

# %%
import pandas as pd

dataset = pd.read_csv("AQI and Lat Long of Countries.csv")
dataset
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %% [markdown]
# **Check the head of the dataframe

# %%
dataset.head(5)
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value  \
# 0  Russian Federation        Praskoveya         51     Moderate             1
# 1              Brazil  Presidente Dutra         41         Good             1
# 2              Brazil  Presidente Dutra         41         Good             1
# 3               Italy   Priolo Gargallo         66     Moderate             1
# 4              Poland         Przasnysz         34         Good             1
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value  \
# 0            Good               36               Good              0
# 1            Good                5               Good              1
# 2            Good                5               Good              1
# 3            Good               39               Good              2
# 4            Good               34               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat      lng
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16393 non-null  object
#  1   City                16695 non-null  object
#  2   AQI Value           16695 non-null  int64
#  3   AQI Category        16695 non-null  object
#  4   CO AQI Value        16695 non-null  int64
#  5   CO AQI Category     16695 non-null  object
#  6   Ozone AQI Value     16695 non-null  int64
#  7   Ozone AQI Category  16695 non-null  object
#  8   NO2 AQI Value       16695 non-null  int64
#  9   NO2 AQI Category    16695 non-null  object
#  10  PM2.5 AQI Value     16695 non-null  int64
#  11  PM2.5 AQI Category  16695 non-null  object
#  12  lat                 16695 non-null  float64
#  13  lng                 16695 non-null  float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# **Check which all cities have AQI value 50 or below 50 **

# %%
dataset[dataset['AQI Value']<=50]
# Out:
#                                                  Country              City  \
# 1                                                 Brazil  Presidente Dutra
# 2                                                 Brazil  Presidente Dutra
# 4                                                 Poland         Przasnysz
# 10                                           Netherlands            Raalte
# 14                                                Poland         Piaseczno
# ...                                                  ...               ...
# 16677                                            Germany        Eberswalde
# 16683                                              Japan           Tatsuno
# 16687                           United States of America           El Reno
# 16688  United Kingdom of Great Britain and Northern I...           Urmston
# 16693                                             France            Sceaux
#
# ...

# %% [markdown]
# **Check which all cities having AQI category moderate**

# %%
dataset[dataset['AQI Category']=='Moderate']
# Out:
#                         Country              City  AQI Value AQI Category  \
# 0            Russian Federation        Praskoveya         51     Moderate
# 3                         Italy   Priolo Gargallo         66     Moderate
# 5      United States of America       Punta Gorda         54     Moderate
# 6      United States of America       Punta Gorda         54     Moderate
# 7                       Belgium             Puurs         64     Moderate
# ...                         ...               ...        ...          ...
# 16685                  Colombia           Viterbo         55     Moderate
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16694  United States of America       Westerville         71     Moderate
#
#        CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category  \
# ...

# %% [markdown]
# **Sort the datafrmae by AQI value**

# %%
dataset.sort_values('AQI Value').head(20)
# Out:
#                                 Country                City  AQI Value  \
# 6610                            Ecuador               Macas          7
# 16559                  Papua New Guinea                Tari          8
# 10496                           Ecuador             Azogues          8
# 5451                               Peru              Huaraz          9
# 6884                          Indonesia           Manokwari         10
# 2615                            Ecuador          Nueva Loja         10
# 5654                               Peru        Huancavelica         10
# 15844                            Brazil          Correntina         11
# 12220                              Peru          Huamachuco         11
# 7348                          Argentina       Puerto Madryn         11
# 16615                         Argentina            La Rioja         11
# 14134                           Uruguay               Young         11
# ...

# %% [markdown]
# **group by and count method**

# %%
dataset.groupby('Country').count()
# Out:
#                                     City  AQI Value  AQI Category  \
# Country
# Afghanistan                            3          3             3
# Albania                                9          9             9
# Algeria                                4          4             4
# Andorra                                1          1             1
# Angola                                21         21            21
# ...                                  ...        ...           ...
# Venezuela (Bolivarian Republic of)    66         66            66
# Viet Nam                               7          7             7
# Yemen                                  3          3             3
# Zambia                                28         28            28
# Zimbabwe                              29         29            29
#
#                                     CO AQI Value  CO AQI Category  \
# Country
# Afghanistan                                    3                3
# ...

# %%
dataset.groupby('Country').max()
# Out:
#                                           City  AQI Value  \
# Country
# Afghanistan                             Zaranj        133
# Albania                                 Tirana        115
# Algeria                               Timizart        154
# Andorra                                 Encamp         32
# Angola                                   Sumbe        285
# ...                                        ...        ...
# Venezuela (Bolivarian Republic of)      Zaraza        163
# Viet Nam                                  Vinh        181
# Yemen                                      Ibb        156
# Zambia                                 Sesheke        125
# Zimbabwe                            Zvishavane         93
#
#                                                       AQI Category  \
# Country
# Afghanistan                         Unhealthy for Sensitive Groups
# Albania                             Unhealthy for Sensitive Groups
# ...

# %%
dataset.groupby('Country').describe().transpose()
# Out:
# Country                Afghanistan     Albania     Algeria  Andorra  \
# AQI Value       count     3.000000    9.000000    4.000000   1.0000
#                 mean     86.333333   77.111111  106.250000  32.0000
#                 std      40.426889   24.705487   34.412934      NaN
#                 min      62.000000   44.000000   74.000000  32.0000
#                 25%      63.000000   67.000000   86.750000  32.0000
#                 50%      64.000000   71.000000   98.500000  32.0000
#                 75%      98.500000   91.000000  118.000000  32.0000
#                 max     133.000000  115.000000  154.000000  32.0000
# CO AQI Value    count     3.000000    9.000000    4.000000   1.0000
#                 mean      0.333333    1.000000    4.000000   1.0000
#                 std       0.577350    0.000000    4.242641      NaN
#                 min       0.000000    1.000000    0.000000   1.0000
#                 25%       0.000000    1.000000    2.250000   1.0000
# ...

# %% [markdown]
# **Get dataset contains specific columns**

# %%
dataset[['Country','City','AQI Value','AQI Category']]
# Out:
#                         Country              City  AQI Value AQI Category
# 0            Russian Federation        Praskoveya         51     Moderate
# 1                        Brazil  Presidente Dutra         41         Good
# 2                        Brazil  Presidente Dutra         41         Good
# 3                         Italy   Priolo Gargallo         66     Moderate
# 4                        Poland         Przasnysz         34         Good
# ...                         ...               ...        ...          ...
# 16690  United States of America  Highland Springs         54     Moderate
# 16691                  Slovakia            Martin         71     Moderate
# 16692                  Slovakia            Martin         71     Moderate
# 16693                    France            Sceaux         50         Good
# 16694  United States of America       Westerville         71     Moderate
#
# [16695 rows x 4 columns]

# %% [markdown]
# **Import matplotlib and define x and y axis of a dataset**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df_dataset = dataset.head(1000)
x = df_dataset['City']
y = df_dataset['AQI Value']
print(x)
print(y)
# Out:
# 0            Praskoveya
# 1      Presidente Dutra
# 2      Presidente Dutra
# 3       Priolo Gargallo
# 4             Przasnysz
#              ...
# 995             Mogocha
# 996             Moncada
# 997             Moncada
# 998             Moncada
# 999          Monfalcone
# Name: City, Length: 1000, dtype: object
# 0      51
# 1      41
# 2      41
# 3      66
# 4      34
#        ..
# 995    31
# 996    28
# 997    28
# 998    28
# 999    64
# Name: AQI Value, Length: 1000, dtype: int64

# %% [markdown]
# **Create a bar graph**

# %%
    plt.bar(x,y)
    plt.xlabel('City')
    plt.ylabel('AQI Value')
    plt.title("Air Quality Index")
    plt.show()

# %% [markdown]
# **Create a simple line graph**

# %%
plt.plot(x,y)
